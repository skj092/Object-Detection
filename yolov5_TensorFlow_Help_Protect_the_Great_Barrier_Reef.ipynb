# %% [markdown]
# <a href="https://colab.research.google.com/github/skj092/Object-Detection/blob/main/yolov5_TensorFlow_Help_Protect_the_Great_Barrier_Reef.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !touch kaggle.json

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle competitions download -c tensorflow-great-barrier-reef
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /content/kaggle.json'
# Downloading tensorflow-great-barrier-reef.zip to /content
# 100% 14.2G/14.2G [02:18<00:00, 79.5MB/s]
# 100% 14.2G/14.2G [02:18<00:00, 110MB/s]

# %%
import zipfile
with zipfile.ZipFile("tensorflow-great-barrier-reef.zip", "r") as zip_ref:
    zip_ref.extractall(".")

# %%
# !rm tensorflow-great-barrier-reef.zip

# %%
import numpy as np
import pandas as pd
from shutil import copyfile

# %%
train = pd.read_csv('train.csv')
train['pos'] = train.annotations != '[]'

# %%
# !mkdir -p ./yolo_data/fold1/images/val
# !mkdir -p ./yolo_data/fold1/images/train

# !mkdir -p ./yolo_data/fold1/labels/val
# !mkdir -p ./yolo_data/fold1/labels/train

# %%
fold = 1

annos = []
for i, x in train.iterrows():
    if x.video_id == fold:
        mode = 'val'
    else:
        # train
        mode = 'train'
        if not x.pos: continue
        # val
    copyfile(f'train_images/video_{x.video_id}/{x.video_frame}.jpg',
                f'./yolo_data/fold{fold}/images/{mode}/{x.image_id}.jpg')
    if not x.pos:
        continue
    r = ''
    anno = eval(x.annotations)
    for an in anno:
#            annos.append(an)
        r += '0 {} {} {} {}\n'.format((an['x'] + an['width'] / 2) / 1280,
                                        (an['y'] + an['height'] / 2) / 720,
                                        an['width'] / 1280, an['height'] / 720)
    with open(f'./yolo_data/fold{fold}/labels/{mode}/{x.image_id}.txt', 'w') as fp:
        fp.write(r)

# %%
hyps = '''
# YOLOv5 by Ultralytics, GPL-3.0 license
# Hyperparameters for COCO training from scratch
# python train.py --batch 40 --cfg yolov5m.yaml --weights '' --data coco.yaml --img 640 --epochs 300
# See tutorials for hyperparameter evolution https://github.com/ultralytics/yolov5#tutorials

lr0: 0.01  # initial learning rate (SGD=1E-2, Adam=1E-3)
lrf: 0.1  # final OneCycleLR learning rate (lr0 * lrf)
momentum: 0.937  # SGD momentum/Adam beta1
weight_decay: 0.0005  # optimizer weight decay 5e-4
warmup_epochs: 3.0  # warmup epochs (fractions ok)
warmup_momentum: 0.8  # warmup initial momentum
warmup_bias_lr: 0.1  # warmup initial bias lr
box: 0.05  # box loss gain
cls: 0.5  # cls loss gain
cls_pw: 1.0  # cls BCELoss positive_weight
obj: 1.0  # obj loss gain (scale with pixels)
obj_pw: 1.0  # obj BCELoss positive_weight
iou_t: 0.20  # IoU training threshold
anchor_t: 4.0  # anchor-multiple threshold
# anchors: 3  # anchors per output layer (0 to ignore)
fl_gamma: 0.0  # focal loss gamma (efficientDet default gamma=1.5)
hsv_h: 0.015  # image HSV-Hue augmentation (fraction)
hsv_s: 0.7  # image HSV-Saturation augmentation (fraction)
hsv_v: 0.4  # image HSV-Value augmentation (fraction)
degrees: 0.0  # image rotation (+/- deg)
translate: 0.1  # image translation (+/- fraction)
scale: 0.5  # image scale (+/- gain)
shear: 0.0  # image shear (+/- deg)
perspective: 0.0  # image perspective (+/- fraction), range 0-0.001
flipud: 0.5  # image flip up-down (probability)
fliplr: 0.5  # image flip left-right (probability)
mosaic: 1.0  # image mosaic (probability)
mixup: 0.5  # image mixup (probability)
copy_paste: 0.0  # segment copy-paste (probability)
'''

# %%
data = '''
# Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2, ..]
path: ../yolo_data/fold1/  # dataset root dir
train: images/train  # train images (relative to 'path') 128 images
val: images/val  # val images (relative to 'path') 128 images
test:  # test images (optional)

# Classes
nc: 1  # number of classes
names: ['reef']  # class names


# Download script/URL (optional)
# download: https://ultralytics.com/assets/coco128.zip
'''

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16283, done.
# remote: Counting objects: 100% (180/180), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 16283 (delta 76), reused 89 (delta 32), pack-reused 16103
# Receiving objects: 100% (16283/16283), 15.04 MiB | 24.45 MiB/s, done.
# Resolving deltas: 100% (11112/11112), done.

# %%
with open('./yolov5/data/reef_f1_naive.yaml', 'w') as fp:
    fp.write(data)
with open('./yolov5/data/hyps/hyp.heavy.2.yaml', 'w') as fp:
    fp.write(hyps)

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !ls data/
# Out:
# Argoverse.yaml	  GlobalWheat2020.yaml	ImageNet10.yaml  reef_f1_naive.yaml  VOC.yaml
# coco128-seg.yaml  hyps			ImageNet.yaml	 scripts	     xView.yaml
# coco128.yaml	  ImageNet1000.yaml	images		 SKU-110K.yaml
# coco.yaml	  ImageNet100.yaml	Objects365.yaml  VisDrone.yaml

# %%
# !python train.py --img 3000 --batch 4 --epochs 5 --data reef_f1_naive.yaml --weights yolov5s6.pt --name l6_3600_uflip_vm5_f1 --hyp data/hyps/hyp.heavy.2.yaml
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.1.1-py3-none-any.whl (699 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.8/699.8 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.23.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.16.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Collecting hub-sdk>=0.0.2 (from ultralytics)
#   Downloading hub_sdk-0.0.3-py3-none-any.whl (37 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2023.11.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: hub-sdk, thop, ultralytics
# Successfully installed hub-sdk-0.0.3 thop-0.1.1.post2209072238 ultralytics-8.1.1
# 2024-01-13 07:21:32.823573: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-13 07:21:32.823686: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-13 07:21:32.944818: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# requirements: Ultralytics requirement ['gitpython'] not found, attempting AutoUpdate...
# Collecting gitpython
#   Downloading GitPython-3.1.41-py3-none-any.whl (196 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 1.7 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from gitpython)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 19.3 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.11 gitpython-3.1.41 smmap-5.0.1
#
# requirements: AutoUpdate success ✅ 7.0s, installed 1 package: ['gitpython']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# train: weights=yolov5s6.pt, cfg=, data=reef_f1_naive.yaml, hyp=data/hyps/hyp.heavy.2.yaml, epochs=5, batch_size=4, imgsz=3000, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=l6_3600_uflip_vm5_f1, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: Ultralytics requirement ['Pillow>=10.0.1'] not found, attempting AutoUpdate...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.2.0 which is incompatible.
# Collecting Pillow>=10.0.1
#   Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 16.7 MB/s eta 0:00:00
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# Successfully installed Pillow-10.2.0
#
# requirements: AutoUpdate success ✅ 7.3s, installed 1 package: ['Pillow>=10.0.1']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v7.0-272-gde64179 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.5, fliplr=0.5, mosaic=1.0, mixup=0.5, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 15.1MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s6.pt to yolov5s6.pt...
# 100% 24.8M/24.8M [00:00<00:00, 152MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1    885504  models.common.Conv                      [256, 384, 3, 2]
#   8                -1  1    665856  models.common.C3                        [384, 384, 1]
#   9                -1  1   1770496  models.common.Conv                      [384, 512, 3, 2]
#  10                -1  1   1182720  models.common.C3                        [512, 512, 1]
#  11                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  12                -1  1    197376  models.common.Conv                      [512, 384, 1, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 8]  1         0  models.common.Concat                    [1]
#  15                -1  1    813312  models.common.C3                        [768, 384, 1, False]
#  16                -1  1     98816  models.common.Conv                      [384, 256, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18           [-1, 6]  1         0  models.common.Concat                    [1]
#  19                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  20                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  21                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  22           [-1, 4]  1         0  models.common.Concat                    [1]
#  23                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  24                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  25          [-1, 20]  1         0  models.common.Concat                    [1]
#  26                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  27                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  28          [-1, 16]  1         0  models.common.Concat                    [1]
#  29                -1  1    715008  models.common.C3                        [512, 384, 1, False]
#  30                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  31          [-1, 12]  1         0  models.common.Concat                    [1]
#  32                -1
jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12208.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12209.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12209.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12210.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12210.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12211.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12211.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12212.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12212.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12213.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12213.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12214.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12214.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12215.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12215.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12216.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12216.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12217.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12217.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12218.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12218.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12219.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12219.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12220.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12220.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12221.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12221.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12222.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12222.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12223.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12223.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12224.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12224.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12225.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12225.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12226.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12226.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12227.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12227.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12228.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12228.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12229.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12229.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12230.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12230.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12231.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12231.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12232.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12232.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12233.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12233.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12234.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12234.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12235.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12235.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12236.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12236.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12237.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12237.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12238.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12238.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12239.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12239.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12240.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12240.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12241.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12241.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12242.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12242.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12243.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12243.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12244.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12244.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12245.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12245.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12246.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12246.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/0-12247.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/0-12247.jpg'
# ...
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6404.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6404.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6405.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6405.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6406.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6406.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6407.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6407.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6408.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6408.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6409.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6409.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6410.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6410.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6411.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6411.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6412.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6412.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6413.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6413.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6414.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6414.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6415.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6415.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6416.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6416.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6417.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6417.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6418.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6418.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6419.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6419.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6420.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6420.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6421.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6421.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6422.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6422.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6423.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6423.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6424.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6424.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6486.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6486.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6487.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6487.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6488.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6488.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6489.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6489.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6490.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6490.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6491.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6491.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-6492.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-6492.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7965.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7965.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7966.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7966.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7967.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7967.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7968.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7968.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7969.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7969.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7970.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7970.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7971.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7971.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7972.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7972.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7973.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7973.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7974.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7974.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7975.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7975.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7976.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7976.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7977.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7977.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7978.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7978.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7979.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7979.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7980.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7980.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7981.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7981.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7982.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7982.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7983.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7983.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7984.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7984.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7985.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7985.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7986.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7986.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7987.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7987.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7988.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7988.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7989.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7989.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7990.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7990.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7991.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7991.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7992.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7992.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7993.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7993.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7994.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7994.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7995.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7995.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7996.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7996.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7997.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7997.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7998.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7998.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-7999.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-7999.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8000.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8000.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8001.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8001.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8002.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8002.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8003.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8003.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8004.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8004.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8005.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8005.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8006.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8006.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8007.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8007.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8857.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8857.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8858.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8858.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8859.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8859.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8860.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8860.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8861.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8861.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8862.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8862.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8863.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8863.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8864.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8864.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8865.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8865.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8866.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8866.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8867.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8867.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8868.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8868.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8869.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8869.jpg'
# train: WARNING ⚠️ /content/yolo_data/fold1/images/train/2-8870.jpg: ignoring corrupt image/label: cannot identify image file '/content/yolo_data/fold1/images/train/2-8870.jpg'
# train: WARNING ⚠️ No labels found in /content/yolo_data/fold1/labels/train.cache. See https://docs.ultralytics.com/yolov5/tutorials/train_custom_data
# train: New cache created: /content/yolo_data/fold1/labels/train.cache
# Traceback (most recent call last):
#   File "/content/yolov5/train.py", line 846, in <module>
#     main(opt)
#   File "/content/yolov5/train.py", line 616, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "/content/yolov5/train.py", line 248, in train
#     train_loader, dataset = create_dataloader(
#   File "/content/yolov5/utils/dataloaders.py", line 177, in create_dataloader
#     dataset = LoadImagesAndLabels(
#   File "/content/yolov5/utils/dataloaders.py", line 568, in __init__
#     assert nf > 0 or not augment, f"{prefix}No labels found in {cache_path}, can not start training. {HELP_URL}"
# AssertionError: train: No labels found in /content/yolo_data/fold1/labels/train.cache, can not start training. See https://docs.ultralytics.com/yolov5/tutorials/train_custom_data

# %%
# !ls
# Out:
# benchmarks.py	 data	     LICENSE	     README.md	       segment	       val.py
# CITATION.cff	 detect.py   models	     README.zh-CN.md   train.py        yolov5s6.pt
# classify	 export.py   __pycache__     requirements.txt  tutorial.ipynb
# CONTRIBUTING.md  hubconf.py  pyproject.toml  runs	       utils
